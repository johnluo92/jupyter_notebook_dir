# %% [markdown]
# # Technical Account Manager
#
# https://theice.referrals.selectminds.com/jobs/technical-account-manager-1773
#
# ### <span style="color:blue">Job Purpose</span>
# ICE Data Services, Inc., a subsidiary of Intercontinental Exchange, Inc., is looking for a Technical Account Manager (TAM) to join our New York office. The real-time data-feed division of IDS provides market data and trading infrastructure to the financial services industry, including buy and sell side firms and ISVs.  As a TAM, you will be assigned to a number of strategic, tier 1 and high value customers and will be expected to build up a deep understanding of the real-time IDS services in order to provide the best level of service to our customers.
#
# A TAM is expected to become a technical and content expert in ICE Data Services real-time solutions product portfolio and will act as a domain level expert to the client as well as the Account Management and Sales organization.
#
# Pro-actively organizing customer meetings
#  - technology and content workshops
#  - product and strategy presentations
#  - as well coordinating all efforts around service delivery on an ongoing basis
#  will all be an integral part of the role.
#
#
# ### <span style="color:blue">Responsibilities</span>
# #### <span style="color:green">The Technical Account Manager has essentially 3 key remits across all assigned accounts:</span>
#
# #### <span style="color:blue">1) Maximize current service experience</span>
# - The Technical Account Manager ensures the infrastructure in place is optimized and future proofed to deliver the services in the best possible way.  Any current or future capacity/performance constraints or technology obstacles are understood and mitigated ahead of time
# - The Technical Account Manager purposely navigates and networks within these tier 1 accounts to partner with key business sponsors and technical leads to drive increased adoption and usage of our data across an as wide user and application base as possible
# - The Technical Account Manager has access to key technology, operations and business stakeholders at all assigned accounts and ensures they are aware of and leveraging the latest technologies and features available to derive the most value from the services currently contracted for
# - The Technical Account Manager is aligned with Client Services and is fully up to date on all ongoing service incidents and acts as a point of escalation to help resolve and if necessary, expedite, any perceived issues impacting service
# - In addition, the Technical Account Manager works closely together with Client Services, Delivery, Customer Engineering and Exchange Relations to oversee any project related work (upgrades, migrations, decommissions) as the central point of contact
#
# #### <span style="color:blue">2) Alignment of customer’s service aspirations with ICE Data Services product roadmaps</span>
# - The Technical Account Manager has an expert view on all real-time solutions product roadmaps and ensures the relevant stakeholders on the customer side have a good appreciation of upcoming new content additions, technology enhancements and strategic product launches ahead of time.  The customer has early access to this information to allow for feedback which in turn would be fed into the priority setting by IDS product management and the business leaders
# - The Technical Account Manager has a deep understanding of the tactical and strategic business development roadmaps on the customer side to help drive and align our own product roadmaps accordingly ranging from new or changing content requirements, adaption of or migration to new technologies as well as understanding competitor offerings that might be considered superior and undermine our strategic position if not addressed
#
# #### <span style="color:blue">3) Conduct service satisfaction surveys</span>
# 3) Conduct service satisfaction surveys
# - The Technical Account Manager performs a regular service satisfaction review soliciting feedback from senior stakeholders by means of a formal survey template
# - The survey results allow ICE Data Services to document and score customer satisfaction rates across multiple disciplines, allowing us to trend (and address) the client’s perception of ICE Data Services over time, and understand how we perform relative to other competitor services used
# - The survey results across all Technical Account Manager accounts are summarized in an executive management report on a yearly basis to help drive internal efforts to enhance service and product areas and help accelerate revenue growth
#
# #### <span style="color:blue">Knowledge and Experience</span>
# - 5+ years’ experience in the market data, front office and/or electronic trading domain in a Technical Account Management, Pre-Sales, Support or Product capacity, having had significant exposure to associated technology, terminology, vendors, trading venues, regulation
# - Excellent understanding of financial markets, the trading life cycle and related terminology
# - Content specialist across various asset classes covering real-time data as well a reference and historical data
# - Project management experience
# - Attention to detail in all aspects of work is essential, diligence
# - Confident and professional communicator
# - Logical and methodical at trouble-shooting
# - Comfortable following established processes and procedures
# - Accountability, always putting the client’s interests first
# - Ability to multi-task and prioritize under pressure, while maintaining high quality output and deadlines
# - Excellent time management skills
# - Expert user of Microsoft Excel, Visio, PowerPoint
# - Basic understanding of networking, infrastructure and associated protocols
# - UNIX or similar command-line experience (desirable)
# - Programming experience at some level in Java, C# or C++ (desirable)
#
#
# ---
# # <span style="color:red">Potential Interview Questions</span>
#
# ## <span style="color:blue">Tell me about yourself:</span>
#
# #### I am a technology driven person, I try to figure out how things work all the time, and I am not afraid to get my hands dirty with data, code, frameworks or experience new learning opportunities.
#
# #### I love working with people, I know sometimes it may not be our best days, but because we are constantly surrounded by coworkers, clients, and bosses that I have come to really enjoy working alongside them. It's like a giant support structure.
#
# #### I really like nature and parks, they largely preserved an ancient feel... this explains why I am someone who likes and respect tradition, because sometimes it can give us guidance on where our future might lead
#
#
# ## <span style="color:blue">So why did you leave your last position?</span>
#
# #### so I had wanted to come off the project at vanguard when covid19 hit the U.S. in march. and try something new apart from being a full time consultant. So I didn't renew my contract in June and naturally I left the contracting firm in August, and there weren't any new projects.
#
# - alternatively: When my contract was up by June, I came off that project without really any new assignments given there were project freezes and timetable shifts.
#
#
# ## <span style="color:blue">Why do I want to work for ICE? Why do you want this job?</span>
#
# #### ICE would be a great fit because the New York Stock Exchange has been around for 2 centuries, and I have always looked up to and respected the men and women who worked in it. As for ICE Data services, it was acquired in December 2015, shortly after I graduated from college.
# #### Ever since I have shown a passion for investments, financial data, and financial technology. I want to continue to contribute new thought pieces, innovation, and overall more efficient process-driven approach/workflows to a respectable financial technology firm such as ICE.
#
# ## <span style="color:blue">What do I like about this role?</span>
#
# #### I like the sweet spot where responsibilities and requirements come in the form of technical skills and also an understanding of financial clients and their needs
#
# ## <span style="color:blue">Why should ICE hire me?</span>
#
# #### I can be a great asset to the team, by bringing experiences acquired from past roles and being able to deliver value, and help a firm build on its foundations, I have the skills and industry knowledge that most others do not have.
#
#
# ## <span style="color:blue">What can I bring to this role or ICE Data Services</span>
#
# #### Aside from my experiences, I bring a deep rooted passion for the financial markets,  I try to keep up to date on industry news, I would study volatility and how it correlates with other instruments, I would explore strategies and how data could be used, and I reflect on my past roles to consolidate knowledge in the face of new information/experience
#
# ## <span style="color:blue">Where do I see myself in 5 years?</span>
#
# #### I see myself becoming really well-rounded in my role, easily able to connect the pieces when anyone comes to me, and also have a portfolio of accomplishments in contributions my family, my team, and the company
#
#
# ## <span style="color:blue">Who am I?</span>
#
# #### I am an young and ambitious financial technology specialist, and I want to grow with a company and treat it as if it's my family, seeing it grow and adapt.
#
#
# ## <span style="color:blue">What do I want out of this role</span>
# #### I want to continue to learn new skills, expand my network, and build on being an integral part of the team. I want to help capture new markets and break trends.
#
# ## <span style="color:blue">What is your biggest weakness?</span>
# #### I think sometimes I need to take breaks from working and studying so much.. I learned this about myself actually from doing self assessment tests
#
# ## <span style="color:blue">What is your biggest strength?</span>
# #### I am great at solving problems and staying calm while doing so. Recently I took up the task of doing these online coding interview questions and have been building a portfolio of resolutions.
#
# ## <span style="color:blue">What is my biggest accomplishment, what is my biggest failure?</span>
# #### I was able to create a backtesting engine and a trading system with a lot patience, self belief, and courage to explore something that ended up not paying for anything.
# #### This was perhaps also my biggest failure, not anticipating for limitations, or bottlenecks... first time founding a business and taking on too much risk/debt right after college.
#
# ## <span style="color:blue">question</span>
# ---
# # <span style="color:red">Experiences and Knowledge grid</span>
#
# | Experiences and knowledge types from posting| personal experiences and knowledge domain |
# |------|------|
# |work experience 1  | 2 years developing startup hedge fund trade system, backtesting engine|
# |work experience 2  | 1 year supporting bloomberg terminal users|
# |work experience 3  | 2 years developing tools and supporting systems for Vanguard|
# |understanding of markets  | retained knowledge in financial markets, instruments, and overall infrastructure|
# |market knowledge  | brokers, exchanges, sell-side, buyside, various regulators, central banks, fiscal components|
# |domain knowledge | asset classes: equities, index/stock options, futures, some fixed income, some OTC
# |data knowledge | real time data: bid/ask, last, option greeks, volume, intraday data
# |data knowledge 2| reference data: country, security type, classifications, bond maturities, interest pegs/indices
# |data knowledge 3| Environmental, Social, Governance (ESG), alternative data, event driven data, twitter feed
# |investment knowledge| volatility indices, short term, mid term, long term, commodity/equity/credit markets
# |investment knowledge 2| federal reserve FOMC decisions, target fund rate, open market operations
# |investment knowledge 3| fiscal policies, regulatory challenges, direct market listing
# |investment knowledge 4| popularization of ETFs, ETPs, ETNs, access to algorithmic trading
# |technical skills|Network/system infrastructure: client, server, database, services, internet protocol
# |technical skills 2|Network/system infrastructure:
#
# ---
#
#
# # <span style="color:orange">Questions for interviewer or about the job</span>
#
# ### what platform does the TAM spend most of their time on, and what tools does a TAM use to help solve problems and provide clients the best service?
#
# ### Does the TAM work on incident tickets, and what level of technicality and quantity can be expected.
#
# ### are some of the services and technologies provided part of the old Interactive Data Corporation that was acquired by ICE?
#
# ### How do you like working at ICE and in your role?
#
# ### What are some challenges the team is looking to bring resources to resolve?
#
# ### are you seeing more active or passive funds subscripting to your services?
#
# ### CME and CBOE
#
# ### office hours/remote work
#
# ---
# # <span style="color:green">Last Remarks</span>
#
#
# ### I hope you and everyone you know are staying safe from covid19, and
# ### I just want to say that I share a lot of the passion about what your company represents and would to love to experience working with financial data/technology.
#
# ---
#
# # past experiences:
#
# ### new york hedge funds
# - utilized my understanding in financial asset trading and applied them to create an automated trading system.
# - It had order entry, contract information, stop loss/profit attached order, custom strategy, and I even built a backtesting engine to validate what was the strategy.
# - The strategy largely did not perform consistently.
# - Due to the prices of crude oil/natural gas we were trading, the brokerage firm would execute our market order but actually wouldn't get executed due to as how a rep explained it, the price had changed too much to much and as the market order was converted a limit order, it would not get accepted so the broker had to change it quickly and multiple times. This was one technical limitation, another was simply because the entry was normally closer to "worst case" scenario, and so that impacted the level of profitability that was expected. The strategy didn't lose any money, but it also wasn't what it could have been. Overall I learned a lot, and transitioned to another similar role at a prop firm and moved onto Bloomberg as a global data analyst.
#
# ### Bloomberg
# - Bloomberg taught me a lot about what a good company looks like, young, agile, and endearing as the people there all seem to be engrained in their speciality. On a day-to-day I mainly handled entitlement requests from buy-side firms request research access on the Terminal, and because we don't actually own the research, we would liaise with sell-side firms that would eventually approve/disapprove the buy side's requests. We did this in a VBA macro custom built to handle the requests, and we would export the automated request to the terminal for servicing the requests. Once the sell-side sees them, they would add their clients to their research broadcast, enabling them access to content, and tools for better investment strategies and research.
#
# - I built a custom toolset to enable streamlined communication with sell-side clients in support of our efforts in updating the entire research entitlements system due to MIFID II's impact on decoupling research from trading commissions.
# - Another interesting part of the job was the research platform itself, it would take in files from sell-side firms and I had to make sure no issues arose during onboarding them. I created a systematic flowchart to help future analysts to be able to troubleshoot any problems in this area.
#
# ### Vanguard
#
# - Vanguard was centralizaing their reference data for their Global Investment Data Management group responsible for onboarding, clearning, and exporting data using NeoXam's proprietary data management system called DataHub. During onboarding BlackRock right off the bat as I started a consultant at NeoXam, before becoming full-time at Vanguard, I had streamlined the creation of xml import connectors used to digest multiple security asset classes. These security classes and their reference data came into Vanguard's system based on trades placed on Aladdin. The software essentially handled the connectivity, cleaning and storing of data into Vanguard's oracle database for further processing, and eventual dissemination. Our team's system connected to charles river, portfolio management tool, accounting book of records, security pricing, etc. We took in data from many places, including an entirely different system of processes running on the same software in production called investment book of records that managed transactions, corporate actions, positions, cash - the team that oversees the development and support of the IBOR application helps risk teams, the PM tool, and complaince by sourcing centralized data in a similar fashion to what the security reference master team does with index, reference, and pricing data.
# - I mastered the process in creating connectors for importing data from multiple vendors, each might have different file formats, transmission techniques, and overall company/communication structure that required smooth communication and diligent project/time management skills.
# - xml nodes were throwing errors in the scheduler's logs and this had been piling up, but one day caused a failure of that scheduler which negatively affected multiples of other services and scheduled services. This was due to the BlackRock's xml file being read by each individual security type's connector. Because initial plans were to separate these connectors, we did not think about the limitations of the middleware to handle massive amounts of noise from this inefficient process, and so I set on to create a kornshell script involving SED, a unix utility, to parse the large xml trade files and divide them into smaller files by security types so that they can be picked up by each connector without throwing the xml node not found errors
# - the proprietary software was flexible in creating new features, and a missing component was the ability manually enter security reference informations, especially for swaps. So the we were brought together to create for 19 different security asset types' entry forms. I was able to actively manage this project for GIDM and communicate with all stakeholders on both R&D and other project managers that had an interest.
#
#
# - datahub: data dictionary
#
# https://www.youtube.com/watch?v=bFtJpqRhhlk
#
# https://corpgov.law.harvard.edu/2018/07/05/spotify-case-study-structuring-and-executing-a-direct-listing/
